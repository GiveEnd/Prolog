# %% [markdown]
# # Prolog
#
# №1
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# №2
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# №3
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
#
# 1. Отношение «Один-ко-многим»
#
# ![image](https://i.imgur.com/85UOC35.png)
#
# ![image](https://i.imgur.com/aLuYFaR.png)
#
# 2. Отношение «Многие-ко-многим»
#
# ![image](https://i.imgur.com/KT1q6V1.png)
#
# ![image](https://i.imgur.com/aqiENaM.png)
#
# ![image](https://i.imgur.com/WpIfyuu.png)
#
# ![image](https://i.imgur.com/fvIYNdz.png)
#
#
# №4
#
# ![image](https://i.imgur.com/fMzIffO.png)
#
# ![image](https://i.imgur.com/6l6a2Vg.png)
#
# ![image](https://i.imgur.com/J33XYlO.png)
